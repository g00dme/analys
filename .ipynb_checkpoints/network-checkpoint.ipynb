# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms.connectivity import local_node_connectivity
from networkx.algorithms.flow import shortest_augmenting_path
import pygraphviz as pgv
from matplotlib import image as mpimg


adj1={"111":["1_1","1_2"],"121":['1_2','1_4'],"131":["1_1","1_3"],"141":["1_3","1_4"]}
adj2={"211":['2_1','2_2','2_3','2_4','2_6','2_7','2_8'],'221':['2_3','2_4'],
    '222':['2_2','2_5'],'231':['2_1','2_5','2_7'],'232':['2_8']}
adj3={'311':['3_1','3_3','3_4','3_5'],'321':['3_2'],
    '331':['3_3'],'341':['3_1','3_4'],'351':['3_2','3_5']}
number={'1_1':5,'1_2':7,'1_3':8,'1_4':5,'2_1':16,'2_2':15,'2_3':9,'2_4':8,'2_5':6,'2_6':12,'2_7':15,'2_8':11,'3_1':6,'3_2':1,'3_3':6,'3_4':7,'3_5':5}

Gt={1:nx.Graph(adj1),2:nx.Graph(adj2),3:nx.Graph(adj3)}
for x in Gt:
    p=nx.k_edge_augmentation(Gt[x],3)
    Gt[x].add_edges_from(p)
G=nx.Graph()
for x in Gt:
    G=nx.compose(Gt[x],G)
G.add_edges_from([[111,211],[121,221],[131,231]]) #connection between 1 and 2
G.add_edges_from([[311,211],[321,221],[331,231]]) #connection between 3 and 2

G=nx.nx_agraph.to_agraph(G)
G=pgv.AGraph(str(G)[7:],strict=False)


from operator import itemgetter
from itertools import groupby

nodes=G.nodes()
nodes.sort(key=itemgetter(0))
nodes=[[x for x in g] for k,g in groupby(nodes,key=itemgetter(0))]
all_common=[]
all_rule=[]
for k,n in zip(range(3),nodes):
    A=G.add_subgraph(n,name=f'cluster{k}',label=f'Здание {k+1}',pencolor='blue')
    rule=[x for x in n if '_' not in x]
    all_rule.extend(rule)
    A.add_subgraph(rule,name=f's{k+5}',rank='same')
    common=[x for x in n if '_'  in x]
    all_common.extend(common)
    A.add_subgraph(common,name=f's{k+10}',rank='same')
G.graph_attr['newrank']='true'

rule=list(adj1.keys())  # 1 и 3 здание на одном уровне
rule.extend(list(adj3.keys()))

G.add_subgraph(rule,name='s89',rank='same')


for x in G:
    n=G.get_node(x)
    n.attr["shape"] = "box"
    n.attr['fontcolor']='blue'
    n.attr['labelfontsize']='10'
    n.attr["imagescale"] = "true"
    n.attr["image"] = 'icons8-switch-50.png'
G.add_edge('s','111')

n=G.get_node('s')
n.attr['shape']='box'
n.attr['image']='icons8-router-symbol-80.png'

net=[]
nodes=G.nodes()
for x in nodes:   
    e=0
    for y in G.edges(x):
        if y[0]==x:
            j=G.get_edge(*y)
            j.attr['taillabel']=f'e{e}'
            j.attr['labelfontsize']=9
            e+=1
        else:
            j=G.get_edge(*y)
            j.attr['headlabel']=f'e{e}'
            j.attr['labelfontsize']=9
            e+=1
    if x in all_common:
        if number[x]<2:
            G.add_edge(x,f'{x}_1')
            n=G.get_node(f'{x}_1')
            n.attr["shape"] = "box"
            n.attr["imagescale"] = "true"
            n.attr["image"] = 'icons8-my-computer-64.png'
            n.attr['label']=''
            j=G.get_edge(x,f'{x}_1')
            j.attr['taillabel']=f'e{e}'
            j.attr['headlabel']=f'e0'
            j.attr['labelfontsize']=9
            
        if number[x]==2:
            G.add_edge(x,f'{x}_1')
            n=G.get_node(f'{x}_1')
            n.attr["shape"] = "box"
            n.attr["imagescale"] = "true"
            n.attr["image"] = 'icons8-my-computer-64.png'
            n.attr['label']=''
            j=G.get_edge(x,f'{x}_1')
            j.attr['taillabel']=f'e{e}'
            j.attr['headlabel']=f'e0'
            j.attr['labelfontsize']=9

            e+=number[x]
            G.add_edge(x,f'{x}_2')
            j=G.get_edge(x,f'{x}_2')
            j.attr['taillabel']=f'e{e}'
            j.attr['headlabel']=f'e0'
            j.attr['labelfontsize']=9

        if number[x]>=2:
            G.add_node(f'{x}_b',shape='none',label='''<
            <TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0">
               <TR><TD PORT='0' SIDES='LTB'><IMG SRC='icons8-my-computer-64.png'/></TD><TD PORT="f1" SIDES='TB'>...</TD><TD PORT='1' SIDES='RTB'><IMG SRC='icons8-my-computer-64.png'/></TD></TR>
            </TABLE>
               >''')
            G.add_edge(x,f'{x}_b',headport='0',taillabel=f'e{e}',headlabel='e0',labelfontsize=9,portPos='ne')            
            e+=number[x]
            G.add_edge(x,f'{x}_b',headport='1',taillabel=f'e{e}',headlabel='e0',labelfontsize=9,portPos='nw')            
            net.extend([f'{x}_b'])

G.graph_attr['splines']='ortho'

G.layout('dot')
G.draw('output.png')

G
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7df8bc0c2040>>

# %%
G1=str(G)

# %%
        # net.extend([f'{x}_1'])
        # G.add_edge(x,f'{x}_1')
        # j=G.get_edge(x,f'{x}_1')
        # j.attr['taillabel']=f'e{e}'
        # j.attr['headlabel']=f'e0'
        # j.attr['labelfontsize']=9
        # if number[x]>=2:
        #     e+=number[x]
        #     G.add_edge(x,f'{x}_2')
        #     j=G.get_edge(x,f'{x}_2')
        #     j.attr['taillabel']=f'e{e}'
        #     j.attr['headlabel']=f'e0'
        #     j.attr['labelfontsize']=9
        #     net.extend([f'{x}_2'])



# # print(nx.edge_connectivity(n))

# image = mpimg.imread("output.png")
# plt.imshow(image)
